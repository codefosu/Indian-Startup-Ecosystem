# %%
import pandas as pd
import numpy as np
d18 = pd.read_csv("startup_funding2018.csv")

d18['AmountInUSD'] = d18['Amount']
d18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company  AmountInUSD
# 0  TheCollegeFever is a hub for fun, fiesta and f...       250000
# 1  A startup which aggregates milk from dairy far...  ₹40,000,000
# 2          Leading Online Loans Marketplace in India  ₹65,000,000
# 3  PayMe India is an innovative FinTech organizat...      2000000
# 4  Eunimart is a one stop solution for merchants ...            —

# %%
# Define a function to determine the currency
def determine_currency(amount):
    if '₹' in amount:
        return 'rupee'
    else:
        return 'dollar'

# Add a new column 'currency' to the DataFrame
d18['currency'] = d18['Amount'].apply(determine_currency)

# Print the first 5 rows of the DataFrame
d18.head()

d18['Amount']=d18['Amount'].str.replace('₹','')
d18['Amount']=d18['Amount'].str.replace(',','')
d18['Amount'] = pd.to_numeric(d18['Amount'], errors='coerce')

# Filter the DataFrame to include only rows with 'Rupees'
rupees_df = d18[d18['currency'] == 'rupee']

# Example modification: converting amounts to dollars in rupees_df
conversion_rate = 70  # 70 Rupees to 1 Dollar
rupees_df['Amount'] = round((rupees_df['Amount'] / conversion_rate),2)


# Display the new DataFrame
rupees_df.head()

# Remove the original rows with 'Rupees' from the original DataFrame
d18 = d18[d18['currency'] != 'rupee']

# Concatenate the modified rupees_df back to the original DataFrame
updated_df = pd.concat([d18, rupees_df], ignore_index=True)

# Display the updated DataFrame
updated_df
# Out:
# C:\Users\efosu\AppData\Local\Temp\ipykernel_9724\3264273199.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rupees_df['Amount'] = round((rupees_df['Amount'] / conversion_rate),2)
#         Company Name                                           Industry  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1        PayMe India                        Financial Services, FinTech
# 2           Eunimart                 E-Commerce Platforms, Retail, SaaS
# 3             Hasura                   Cloud Infrastructure, PaaS, SaaS
# 4       Freightwalla       Information Services, Information Technology
# ..               ...                                                ...
# 521            Nykaa                          Beauty, Fashion, Wellness
# 522          Chaayos                Food and Beverage, Restaurants, Tea
# 523         LT Foods  Food and Beverage, Food Processing, Manufacturing
# 524       Multibashi                               E-Learning, Internet
# 525       Droni Tech                             Information Technology
#
#          Round/Series       Amount                          Location  \
# 0                Seed    250000.00       Bangalore, Karnataka, India
# 1               Angel   2000000.00       Noida, Uttar Pradesh, India
# 2                Seed          NaN  Hyderabad, Andhra Pradesh, India
# 3                Seed   1600000.00       Bengaluru, Karnataka, India
# 4                Seed          NaN        Mumbai, Maharashtra, India
# ..                ...          ...                               ...
# 521  Secondary Market  16142857.14        Mumbai, Maharashtra, India
# 522          Series B  11571428.57           New Delhi, Delhi, India
# 523   Post-IPO Equity  20000000.00           New Delhi, Delhi, India
# 524              Seed    142857.14       Bengaluru, Karnataka, India
# 525              Seed    500000.00        Mumbai, Maharashtra, India
#
#                                          About Company     AmountInUSD  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...          250000
# 1    PayMe India is an innovative FinTech organizat...         2000000
# 2    Eunimart is a one stop solution for merchants ...               —
# 3    Hasura is a platform that allows developers to...         1600000
# 4    Freightwalla is an international forwarder tha...               —
# ..                                                 ...             ...
# 521  Nykaa.com is a premier online beauty and welln...  ₹1,130,000,000
# 522  Chaayos was born in November 2012 out of this ...    ₹810,000,000
# 523  LT Foods believe that nature will continue to ...  ₹1,400,000,000
# 524                   Free language learning platform.     ₹10,000,000
# 525  Droni Tech manufacture UAVs and develop softwa...     ₹35,000,000
#
#     currency
# 0     dollar
# 1     dollar
# 2     dollar
# 3     dollar
# 4     dollar
# ..       ...
# 521    rupee
# 522    rupee
# 523    rupee
# 524    rupee
# 525    rupee
#
# [526 rows x 8 columns]

# %%
# Define a function to determine the currency
def determine_currency(amount):
    if '₹' in amount:
        return 'rupee'
    else:
        return 'dollar'

# Add a new column 'currency' to the DataFrame
d18['currency'] = d18['Amount'].apply(determine_currency)

# Print the first 5 rows of the DataFrame
d18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company  AmountInUSD currency
# 0  TheCollegeFever is a hub for fun, fiesta and f...       250000   dollar
# 1  A startup which aggregates milk from dairy far...  ₹40,000,000    rupee
# 2          Leading Online Loans Marketplace in India  ₹65,000,000    rupee
# 3  PayMe India is an innovative FinTech organizat...      2000000   dollar
# 4  Eunimart is a one stop solution for merchants ...            —   dollar

# %%
d18.head(10)
# Out:
#          Company Name                                           Industry  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# 5              Hasura                   Cloud Infrastructure, PaaS, SaaS
# 6           Tripshelf                     Internet, Leisure, Marketplace
# 7        Hyperdata.IO                                    Market Research
# 8        Freightwalla       Information Services, Information Technology
# 9  Microchip Payments                                    Mobile Payments
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
# 5         Seed      1600000       Bengaluru, Karnataka, India
# 6         Seed  ₹16,000,000             Kalkaji, Delhi, India
# 7        Angel  ₹50,000,000  Hyderabad, Andhra Pradesh, India
# 8         Seed            —        Mumbai, Maharashtra, India
# 9         Seed            —       Bangalore, Karnataka, India
#
#                                        About Company  AmountInUSD currency
# 0  TheCollegeFever is a hub for fun, fiesta and f...       250000   dollar
# 1  A startup which aggregates milk from dairy far...  ₹40,000,000    rupee
# 2          Leading Online Loans Marketplace in India  ₹65,000,000    rupee
# 3  PayMe India is an innovative FinTech organizat...      2000000   dollar
# 4  Eunimart is a one stop solution for merchants ...            —   dollar
# 5  Hasura is a platform that allows developers to...      1600000   dollar
# 6  Tripshelf is an online market place for holida...  ₹16,000,000    rupee
# 7  Hyperdata combines advanced machine learning w...  ₹50,000,000    rupee
# 8  Freightwalla is an international forwarder tha...            —   dollar
# 9  Microchip payments is a mobile-based payment a...            —   dollar

# %%
d18['Amount']=d18['Amount'].str.replace('₹','')
d18['Amount']=d18['Amount'].str.replace(',','')
d18['Amount'] = pd.to_numeric(d18['Amount'], errors='coerce')

# %%
# Filter the DataFrame to include only rows with 'Rupees'
rupees_df = d18[d18['currency'] == 'rupee']

# Example modification: converting amounts to dollars in rupees_df
conversion_rate = 70  # 70 Rupees to 1 Dollar
rupees_df['Amount'] = round((rupees_df['Amount'] / conversion_rate),2)


# Display the new DataFrame
rupees_df.head()
# Out:
# C:\Users\efosu\AppData\Local\Temp\ipykernel_29292\2371525172.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rupees_df['Amount'] = round((rupees_df['Amount'] / conversion_rate),2)
#        Company Name                                          Industry  \
# 1   Happy Cow Dairy                              Agriculture, Farming
# 2        MyLoanCare  Credit, Financial Services, Lending, Marketplace
# 6         Tripshelf                    Internet, Leisure, Marketplace
# 7      Hyperdata.IO                                   Market Research
# 15          Pitstop       Automotive, Search Engine, Service Industry
#
#    Round/Series      Amount                          Location  \
# 1          Seed   571428.57        Mumbai, Maharashtra, India
# 2      Series A   928571.43           Gurgaon, Haryana, India
# 6          Seed   228571.43             Kalkaji, Delhi, India
# 7         Angel   714285.71  Hyderabad, Andhra Pradesh, India
# 15         Seed  1428571.43       Bengaluru, Karnataka, India
#
#                                         About Company   AmountInUSD currency
# 1   A startup which aggregates milk from dairy far...   ₹40,000,000    rupee
# 2           Leading Online Loans Marketplace in India   ₹65,000,000    rupee
# 6   Tripshelf is an online market place for holida...   ₹16,000,000    rupee
# 7   Hyperdata combines advanced machine learning w...   ₹50,000,000    rupee
# 15  Pitstop offers general repair and maintenance ...  ₹100,000,000    rupee

# %%
# Remove the original rows with 'Rupees' from the original DataFrame
d18 = d18[d18['currency'] != 'rupee']

# Concatenate the modified rupees_df back to the original DataFrame
updated_df = pd.concat([d18, rupees_df], ignore_index=True)

# Display the updated DataFrame
updated_df
# Out:
#         Company Name                                           Industry  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1        PayMe India                        Financial Services, FinTech
# 2           Eunimart                 E-Commerce Platforms, Retail, SaaS
# 3             Hasura                   Cloud Infrastructure, PaaS, SaaS
# 4       Freightwalla       Information Services, Information Technology
# ..               ...                                                ...
# 521            Nykaa                          Beauty, Fashion, Wellness
# 522          Chaayos                Food and Beverage, Restaurants, Tea
# 523         LT Foods  Food and Beverage, Food Processing, Manufacturing
# 524       Multibashi                               E-Learning, Internet
# 525       Droni Tech                             Information Technology
#
#          Round/Series       Amount                          Location  \
# 0                Seed    250000.00       Bangalore, Karnataka, India
# 1               Angel   2000000.00       Noida, Uttar Pradesh, India
# 2                Seed          NaN  Hyderabad, Andhra Pradesh, India
# 3                Seed   1600000.00       Bengaluru, Karnataka, India
# 4                Seed          NaN        Mumbai, Maharashtra, India
# ..                ...          ...                               ...
# 521  Secondary Market  16142857.14        Mumbai, Maharashtra, India
# 522          Series B  11571428.57           New Delhi, Delhi, India
# 523   Post-IPO Equity  20000000.00           New Delhi, Delhi, India
# 524              Seed    142857.14       Bengaluru, Karnataka, India
# 525              Seed    500000.00        Mumbai, Maharashtra, India
#
#                                          About Company     AmountInUSD  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...          250000
# 1    PayMe India is an innovative FinTech organizat...         2000000
# 2    Eunimart is a one stop solution for merchants ...               —
# 3    Hasura is a platform that allows developers to...         1600000
# 4    Freightwalla is an international forwarder tha...               —
# ..                                                 ...             ...
# 521  Nykaa.com is a premier online beauty and welln...  ₹1,130,000,000
# 522  Chaayos was born in November 2012 out of this ...    ₹810,000,000
# 523  LT Foods believe that nature will continue to ...  ₹1,400,000,000
# 524                   Free language learning platform.     ₹10,000,000
# 525  Droni Tech manufacture UAVs and develop softwa...     ₹35,000,000
#
#     currency
# 0     dollar
# 1     dollar
# 2     dollar
# 3     dollar
# 4     dollar
# ..       ...
# 521    rupee
# 522    rupee
# 523    rupee
# 524    rupee
# 525    rupee
#
# [526 rows x 8 columns]

# %%
def clean_amount(amount):
    try:
        if d18['currency']=='rupee':
            d18['Amount'] = d18['Amount']/70
            return d18['Amount']
        else:
            return d18['Amount']
    except ValueError:
        return amount

# Apply the clean_amount function to the 'Amount' column
d18['Amount'] = d18['Amount'].apply(clean_amount)
